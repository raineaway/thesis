# %%
import os
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC, SVC
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import StratifiedKFold

import pandas as pd
import pprint
from ast import literal_eval

from random import randint

# %%
corpus = pd.read_csv('gm_fake_or_real_equal.csv');

data = []
labels = []
for news in corpus['text']:
    data.append(news)

for news in corpus['class']:
    labels.append(news)

print "Total number of articles: " + str(len(data))
# Out:
# Total number of articles: 6256

# %%
def ksplit(data, n):
    count = len(data)/n
    idx = []
    kf = StratifiedKFold(n_splits=n)
    for train, test in kf.split(data, )
# Out:
#          id                                               text  class
# 0      8230  Report Copyright Violation OFFICIAL ONLINE NAT...      1
# 5      5990  Urban Population Booms Will Make Climate Chang...      1
# 6      6051  Get short URL 0 3 0 0 Buddy Blackwell asked hi...      1
# 7      8552  Can nuclear war break out on the Korean Penins...      1
# 10     9988  Lara Trump Implies FBI Letter Politically Moti...      1
# 11     8085  November 2, 2016 Will Obama recognize Palestin...      1
# 13     6147  Man uses Trump victory as excuse to call ex-gi...      1
# 14     9324  Trump Raises Concern Over Members Of Urban Com...      1
# 15    10209    This Times newspaper correction is amusing \...      1
# 17     7294  Home / Be The Change / Government Corruption /...      1
# 18     6211  Reuters \nOn a rooftop overlooking the walls o...      1
# 20     9618  Here is President Putin’s speech at Valdai Put...      1
# 22     7655  Posted on October 28, 2016 by Michael Snyder \...      1
# 23     5759  DNC Head Leaked 2nd Debate Question to Hillary...      1
# 24     7314  Archives Michael On Television 22 Reasons Why ...      1
# 28     8016  It has been said a number of times over the pa...      1
# 32     6067  The topic of Unidentified Flying Objects (UFOs...      1
# 33     9222  By Reuters   5:51 pm Democratic nominee Hillar...      1
# 36     9786  Share on Facebook \nRepublicans in Congress an...      1
# 37     6054  0 comments Obama was speaking to donors at a p...      1
# 38     7697  in: News Articles , Preparedness\Survival Back...      1
# 39    10248  Next Prev Swipe left/right A perfect mashup of...      1
# 40     9102  A guide to the Paradoxroutine page: 1 Hah I'm ...      1
# 42     6111  Home | World | Britain No Longer a Sovereign D...      1
# 46     6377  \nIf you’re following the news, you know FBI D...      1
# 47     8614  Dr. MacDonald & Dr. Duke Expose the Vicious Wa...      1
# 50     7519  Bank of Canada Commentary Whipsaws Loonie   \n...      1
# 52     5587  Legal Insurrection – by Leslie Eastman \nAbout...      1
# 54     5682  — Bernie Sanders (@BernieSanders) October 27, ...      1
# 55     6265  Does anyone like Trump as a person ? The answe...      1
# ...     ...                                                ...    ...
# 6210   9379  — Kombiz Lavasany (@kombiz) October 29, 2016 \...      1
# 6212  10170  Swiss volunteer firefighters: It’s ok to be a ...      1
# 6214   9912  Speaker At Trump Rally Says He Hopes Hillary C...      1
# 6217   7751  Back Story Of FBI’s Hillary Cover-Up FBI corru...      1
# 6218   6033  by Yves Smith \nYves here. This is a very impo...      1
# 6220   7689  Scientists have heard unusual messages from de...      1
# 6221   6815  0 Add Comment \nRATHER than relax and play Tex...      1
# 6222   8799  Subscribe \nIn politics, the Third Way is a po...      1
# 6224   8067  October Sky, Good Harbor Beach MA(image by Ric...      1
# 6226   8915  Embargo Remains Politically Contentious Within...      1
# 6227   9527  Donald Trump is loud, rude, bombastic and just...      1
# 6228  10053  Clinton Campaign In FULL PANIC After Bill’s Al...      1
# 6230   6335  Home / #Solutions / Colin Kaepernick Just Star...      1
# 6232   5822  \nA chilling Ministry of Foreign Affairs ( MoF...      1
# 6233   5673  Research could ‘potentially serve as a curativ...      1
# 6234   8338  Home › POLITICS › BECK: COMEY LETTER ‘ONE OF T...      1
# 6235   5855  Dakota Pipeline Protests Are Working! One Bank...      1
# 6236  10116  Breitbart – by Deborah Danan \nTEL AVIV – Dona...      1
# 6238   8082  The Washington Post reported : \nDonald Trump ...      1
# 6240   6934  America’s Streets Will Run With Blood- Mike Ad...      1
# 6242   7416  AT&T sold access to customer data to law enfor...      1
# 6243   9930  Hillary Clinton Waiting In Wings Of Stage Sinc...      1
# 6245   9470  Donald Trump was rushed from a rally stage by ...      1
# 6246   8268  10 Views November 02, 2016 GOLD , KWN King Wor...      1
# 6249  10021  posted by Eddie Got VHS tapes collecting dust ...      1
# 6250   7569  Friday 4 November 2016 by Davywavy NewsThump d...      1
# 6251   6220  Home › POLITICS | US NEWS › BLOOMBERG-BACKED P...      1
# 6252   8124  Crack in Earth’s magnetic shield detected 11/0...      1
# 6254   6102  Sex and the Presidential City Sex and the Pres...      1
# 6255   9381  BNI Store Nov 4 2016 Wife of Muslim jihadist w...      1
#
# [3128 rows x 3 columns]

# %%
len(data)/10
# Out:
# 625
