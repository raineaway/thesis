# %% [markdown]
# # Dataset Analysis
#
# This notebook provides information about the input dataset.

# %% [markdown]
# First, we import the required packages.

# %%
import pandas as pd
import numpy as np
import csv
from sklearn.feature_extraction import text 
from nltk.corpus import stopwords
import string

# %% [markdown]
# Read the dataset into a dataframe. Remove any rows with empty text values.

# %%
dataset = pd.read_csv('fake_or_real_news.csv', sep=',', error_bad_lines=True,
                      usecols=['id', 'text', 'label']);
dataset['text'].replace(' ', np.nan, inplace=True)
dataset.dropna(subset=['text'], inplace=True)
print "Total number of articles: " + str(len(dataset))
# Out:
# Total number of articles: 6299

# %% [markdown]
# ### Extract some information from the dataset.
#
# #### Setup: Get the stop words to remove from retrieving corpus information

# %%
stop_words = text.ENGLISH_STOP_WORDS.union(['.', ',', '-', '–', '—', '--'])

# %% [markdown]
# ### Fake Articles

# %%
fake_corpus = dataset[dataset['label'] == 'FAKE']

print "Total number of fake articles: " + str(len(fake_corpus))
print "\n"

print "Number of words statistics: "
words = fake_corpus['text'].apply(lambda x: len(x.lower().split()))
print words.describe()
print "\n"

print "Top 25 words: "
words = fake_corpus['text']
words = words.apply(lambda x: x.translate(None, string.punctuation))
words = words.str.lower().str.split()
words = words.apply(lambda x: [item for item in x if item not in stop_words])
flat = [item for sublist in words for item in sublist]
pd.Series(flat).value_counts().nlargest(25)
# Out:
# Total number of fake articles: 3128
#
#
# Number of words statistics:
# count     3128.000000
# mean       686.938299
# std        961.676838
# min          1.000000
# 25%        217.750000
# 50%        427.500000
# 75%        835.000000
# max      20891.000000
# Name: text, dtype: float64
#
#
# Top 25 words:
# trump         5620
# clinton       5579
# people        5072
# hillary       4074
# said          3974
# just          3535
# new           3447
# like          3182
# election      2894
# world         2794
# time          2782
# state         2657
# 2016          2589
# government    2564
# president     2421
# war           2329
# american      2326
# states        2219
# it’s          2147
# years         2146
# campaign      2064
# media         2027
# know          1937
# obama         1891
# donald        1830
# dtype: int64

# %% [markdown]
# #### Real Articles

# %%
real_corpus = dataset[dataset['label'] == 'REAL']

print "Total number of real articles: " + str(len(real_corpus))
print "\n"

print "Number of words statistics: "
words = real_corpus['text'].apply(lambda x: len(x.lower().split()))
print words.describe()
print "\n"

print "Top 25 words: "
words = real_corpus['text']
words = words.apply(lambda x: x.translate(None, string.punctuation))
words = words.str.lower().str.split()
words = words.apply(lambda x: [item for item in x if item not in stop_words])
flat = [item for sublist in words for item in sublist]
pd.Series(flat).value_counts().nlargest(25)
# Out:
# Total number of real articles: 3171
#
#
# Number of words statistics:
# count    3171.000000
# mean      870.101230
# std       719.419773
# min         7.000000
# 25%       449.000000
# 50%       769.000000
# 75%      1119.000000
# max      7599.000000
# Name: text, dtype: float64
#
#
# Top 25 words:
# said            16972
# trump           12383
# clinton          8633
# people           5891
# new              5695
# president        5523
# state            5471
# campaign         5279
# republican       4814
# obama            4593
# states           3964
# just             3793
# like             3778
# time             3556
# party            3488
# sanders          3461
# house            3407
# political        3292
# voters           3107
# republicans      3099
# presidential     3031
# percent          3020
# democratic       2996
# going            2919
# told             2839
# dtype: int64

# %% [markdown]
# ### Convert the labels to binary

# %%
label = {'FAKE':1, 'REAL':0}
dataset["label"].replace(label, inplace=True)
dataset
# Out:
#          id                                               text  label
# 0      8476  Daniel Greenfield, a Shillman Journalism Fello...      1
# 1     10294  Google Pinterest Digg Linkedin Reddit Stumbleu...      1
# 2      3608  U.S. Secretary of State John F. Kerry said Mon...      0
# 3     10142  — Kaydee King (@KaydeeKing) November 9, 2016 T...      1
# 4       875  It's primary day in New York and front-runners...      0
# 5      6903    \nI’m not an immigrant, but my grandparents ...      1
# 6      7341  Share This Baylee Luciani (left), Screenshot o...      1
# 7        95  A Czech stockbroker who saved more than 650 Je...      0
# 8      4869  Hillary Clinton and Donald Trump made some ina...      0
# 9      2909  Iranian negotiators reportedly have made a las...      0
# 10     1357  CEDAR RAPIDS, Iowa — “I had one of the most wo...      0
# 11      988  Donald Trump’s organizational problems have go...      0
# 12     7041  Click Here To Learn More About Alexandra's Per...      1
# 13     7623  October 31, 2016 at 4:52 am \nPretty factual e...      1
# 14     1571  Killing Obama administration rules, dismantlin...      0
# 15     4739  As more women move into high offices, they oft...      0
# 16     7737  Shocking! Michele Obama & Hillary Caught Glamo...      1
# 17     8716  0 \nHillary Clinton has barely just lost the p...      1
# 18     3304  Washington (CNN) For months, the White House a...      0
# 19     3078  While paging through Pew's best data visualiza...      0
# 20     2517  With little fanfare this fall, the New York de...      0
# 21    10348  November 13, 2016 By 21wire Leave a Comment \n...      1
# 22      778  Hillary Clinton told a Staten Island crowd tod...      0
# 23     3300  Mitch McConnell has an unusual admonition for ...      0
# 24     6155  Mises.org November 1, 2016 Inferno is a great ...      1
# 25      636  Washington (CNN) The faction of the GOP that i...      0
# 26      755  Meanwhile, Democrat Bernie Sanders picked up m...      0
# 27      626  After a week of nonstop criticism from Democra...      0
# 28      691  If you want a glimpse into a presidential cand...      0
# 29     5743  Syrian War Report – October 31, 2016: Al-Nusra...      1
# ...     ...                                                ...    ...
# 6304  10417  Obama Furious After Fed-Up ‘Deplorables’ Drop ...      1
# 6305   6457  Print \n[Ed. – Now teaching the gospel of raci...      1
# 6306   7030  Sound too “strange” to be true? We have proof!...      1
# 6307   9013  US abstains from UN vote calling for end to Cu...      1
# 6308   9509  Tuesday 1 November 2016 by Formelia Alberthine...      1
# 6309   3825  When Susan E. Rice took over as President Obam...      0
# 6310   4515  (CNN) ISIS has claimed responsibility for the ...      0
# 6311   2747  It was inevitable that liberals would end up b...      0
# 6312   6516  By Kalee Brown\nWhile I was at university, man...      1
# 6313   9636  Email \nDonald Trump is again riling up his vo...      1
# 6314   7398  BREAKING: Trump Jumps in FL, Takes 4 Point Lea...      1
# 6315   3717  Police in Charleston, S.C., say a man they sus...      0
# 6316   5205  Silver of FiveThirtyEight.com has laid out fou...      0
# 6317   6696  This post was originally published on this sit...      1
# 6318   7991  BREAKING : Hillary Campaign Manager Deletes hi...      1
# 6319   1303  Ted Cruz took first prize in the Iowa caucuses...      0
# 6320   9051  Posted on November 4, 2016 by Charles Hugh Smi...      1
# 6321  10200  Charlie Baker , Massachusetts (2015–present)[3...      1
# 6322  10009  vladimir putin , Valdai , sochi , RBTH Daily R...      1
# 6323   4214  ROME —  U.S. Democratic presidential candidate...      0
# 6324   2316  Most conservatives who oppose marriage equalit...      0
# 6325   8411  Written by Peter Van Buren   venerable New Yor...      1
# 6326   6143  DOJ COMPLAINT: Comey Under Fire Over Partisan ...      1
# 6327   3262  The freshman senator from Georgia quoted scrip...      0
# 6329   8737  Julian Assange has claimed the Hillary Clinton...      1
# 6330   4490  The State Department told the Republican Natio...      0
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...      1
# 6332   8622   Anti-Trump Protesters Are Tools of the Oligar...      1
# 6333   4021  ADDIS ABABA, Ethiopia —President Obama convene...      0
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...      0
#
# [6299 rows x 3 columns]

# %% [markdown]
# ### Write to file

# %%
dataset = dataset.rename(index=str, columns={"label":"class"})
dataset.to_csv(path_or_buf='gm_fake_or_real.csv', columns=['id', 'text', 'class'], index=False)
