# %% [markdown]
# # Stratified k-Fold Cross Validation
#
# ### Vectorizers:
# TFIDF, Token Count
#
# ### Machine Learning Models:
# SVM (linear)
# SVM (RBF)
# Naive Bayes
#
#
# ### Description
# These feature extraction methods and machine learning models are combined and ran using k-fold cross validation, with values of k = 2, 3, and 10. Feature statistics are also extracted for further analysis.

# %% [markdown]
# Import the required packages.

# %%
import os
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC, SVC
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import pandas as pd
import pprint
from ast import literal_eval

from __future__ import print_function


def train(k, data, labels):
    
    kf = StratifiedKFold(n_splits=k)
    
    totalNB_tfidf = 0       # Accuracy measure
    totalMatNB_tfidf = np.zeros((2,2));        # Confusion matrix
    totalNB_count = 0       # Accuracy measure
    totalMatNB_count = np.zeros((2,2));        # Confusion matrix
    
    totalRF_tfidf = 0
    totalMatRF_tfidf = np.zeros((2,2));
    totalRF_count = 0
    totalMatRF_count = np.zeros((2,2));
    
    for train_index, test_index in kf.split(data,labels):
        X_train = [data[i] for i in train_index]
        X_test = [data[i] for i in test_index]
        y_train = [labels[i] for i in train_index]
        y_test = [labels[i] for i in test_index]
        
        tfidfVectorizer = TfidfVectorizer(min_df=5,
                                     max_df = 0.8,
                                     sublinear_tf=True,
                                     use_idf=True,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
        
        countVectorizer = CountVectorizer(min_df=5,
                                     max_df = 0.8,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')

        X_train_tfidf = tfidfVectorizer.fit_transform(X_train) 
        X_test_tfidf = tfidfVectorizer.transform(X_test)
        
        X_train_count = countVectorizer.fit_transform(X_train)
        X_test_count = countVectorizer.transform(X_test)
        
        nbModel = MultinomialNB() 
        nbModel.fit(X_train_tfidf, y_train)
        nbResult = nbModel.predict(X_test_tfidf)
        totalMatNB_tfidf = totalMatNB_tfidf + confusion_matrix(y_test, nbResult)
        totalNB_tfidf = totalNB_tfidf+sum(y_test==nbResult)
        
        #rfModel = RandomForestClassifier(max_depth=2, random_state=0)
        #rfModel.fit(X_train_tfidf, y_train)
        #rfResult = rfModel.predict(X_test_tfidf)
        #totalMatRF_tfidf = totalMatRF_tfidf + confusion_matrix(y_test, rfResult)
        #totalRF_tfidf = totalRF_tfidf+sum(y_test==rfResult)
        
        nbModel = MultinomialNB() 
        nbModel.fit(X_train_count, y_train)
        nbResult = nbModel.predict(X_test_count)
        totalMatNB_count = totalMatNB_count + confusion_matrix(y_test, nbResult)
        totalNB_count = totalNB_count+sum(y_test==nbResult)
        
        #rfModel = RandomForestClassifier(max_depth=2, random_state=0)
        #rfModel.fit(X_train_count, y_train)
        #rfResult = rfModel.predict(X_test_count)
        #totalMatRF_count = totalMatRF_count + confusion_matrix(y_test, rfResult)
        #totalRF_count = totalRF_count+sum(y_test==rfResult)
    
    print("Confusion Matrix for Naive Bayes - TFIDF")
    print(totalMatNB_tfidf)
    print("Accuracy: ")
    print(totalNB_tfidf/count)
    print ()
    
    print("Confusion Matrix for Naive Bayes - Count")
    print(totalMatNB_count)
    print("Accuracy: ")
    print(totalNB_count/count)
    print ()

    
    #print("Confusion Matrix for Random Forests - TFIDF")
    #print(totalMatRF_tfidf)
    #print("Accuracy: ")
    #print(totalRF_tfidf/count)
    #print ()
    
    #print("Confusion Matrix for Random Forests - Count")
    #print(totalMatRF_count)
    #print("Accuracy: ")
    #print(totalRF_count/count)
    #print ()


def trainSVM(k, X_train, X_test, y_train, y_test):
    
    print ("*************** SVM ***************")
    print ()
    
    tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters %s" % score)
        print()

        clf = GridSearchCV(SVC(), tuned_parameters, cv=k,
                           scoring='%s_macro' % score)
        clf.fit(X_train, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test)
        print(classification_report(y_true, y_pred))
        print()

        
def trainRF(k, X_train, X_test, y_train, y_test):
    
    print ("*************** RF ***************")
    print ()
    
    rfc = RandomForestClassifier(max_depth=2, random_state=0)

    param_grid = { 
        'n_estimators': [250, 500, 750, 1000, 1250, 1500],
        'max_features': ['auto', 'sqrt', 'log2']
    }
    
    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters %s" % score)
        print()

        clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=k,
                           scoring='%s_macro' % score)
        clf.fit(X_train, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test)
        print(classification_report(y_true, y_pred))
        print()

# %% [markdown]
# Read the dataset, and create the data and label arrays.

# %%
corpus = pd.read_csv('gm_equal.csv');

data = []
labels = []
for news in corpus['text']:
    data.append(news)

for news in corpus['class']:
    labels.append(news)

print ("Total number of articles: " + str(len(data)))
# Out:
# Total number of articles: 6246

# %% [markdown]
# ## Training and Validation

# %%
#Stratified 10-cross fold validation with SVM and Multinomial NB 
      
kvalues = [2, 3, 10]
count = float(len(data))

for k in kvalues:

    print ("*************************************************")
    print ("Running validation on k = " + str(k))
    print ()
    
    kf = StratifiedKFold(n_splits=k)
    
    
    #Naive Bayes
     
    train(k, data, labels)
    
    
    #SVM
    
    X_train, X_test, y_train, y_test = train_test_split(
        data, labels, test_size=0.5, random_state=0)
    
    
    print ("********** TFIDF **********")
    print ()
    
    tfidfVectorizer = TfidfVectorizer(min_df=5,
                                     max_df = 0.8,
                                     sublinear_tf=True,
                                     use_idf=True,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    X_train_tfidf = tfidfVectorizer.fit_transform(X_train) 
    X_test_tfidf = tfidfVectorizer.transform(X_test)
    
    trainSVM(k, X_train_tfidf, X_test_tfidf, y_train, y_test)
    trainRF(k, X_train_tfidf, X_test_tfidf, y_train, y_test)
    
    
    print ("********** COUNT **********")
    print ()
    
    countVectorizer = CountVectorizer(min_df=5,
                                     max_df = 0.8,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    X_train_count = countVectorizer.fit_transform(X_train)
    X_test_count = countVectorizer.transform(X_test)
    
    trainSVM(k, X_train_count, X_test_count, y_train, y_test)
    trainRF(k, X_train_count, X_test_count, y_train, y_test)
# Out:
# *************************************************
# Running validation on k = 2
#
# Confusion Matrix for Naive Bayes - TFIDF
# [[ 2934.   192.]
#  [  574.  2546.]]
# Accuracy:
# 0.877361511367
#
# Confusion Matrix for Naive Bayes - Count
# [[ 2764.   362.]
#  [  403.  2717.]]
# Accuracy:
# 0.877521613833
#
# ********** TFIDF **********
#
# *************** SVM ***************
#
# # Tuning hyper-parameters precision
# /home/raine/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
#
# {'kernel': 'linear', 'C': 10}
#
# Grid scores on development set:
#
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.879 (+/-0.010) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.922 (+/-0.010) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.879 (+/-0.010) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.920 (+/-0.011) for {'kernel': 'linear', 'C': 1}
# 0.924 (+/-0.011) for {'kernel': 'linear', 'C': 10}
# 0.919 (+/-0.020) for {'kernel': 'linear', 'C': 100}
# 0.919 (+/-0.020) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.93      0.93      1563
#           1       0.93      0.94      0.93      1560
#
# avg / total       0.93      0.93      0.93      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'kernel': 'linear', 'C': 10}
#
# Grid scores on development set:
#
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.868 (+/-0.021) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.921 (+/-0.008) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.868 (+/-0.021) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.919 (+/-0.009) for {'kernel': 'linear', 'C': 1}
# 0.923 (+/-0.010) for {'kernel': 'linear', 'C': 10}
# 0.918 (+/-0.019) for {'kernel': 'linear', 'C': 100}
# 0.918 (+/-0.019) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.93      0.93      1563
#           1       0.93      0.94      0.93      1560
#
# avg / total       0.93      0.93      0.93      3123
#
#
# *************** RF ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 750}
#
# Grid scores on development set:
#
# 0.789 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 250}
# 0.797 (+/-0.023) for {'max_features': 'auto', 'n_estimators': 500}
# 0.795 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 750}
# 0.796 (+/-0.034) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.796 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.795 (+/-0.034) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.789 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.797 (+/-0.023) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.795 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.796 (+/-0.034) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.796 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.795 (+/-0.034) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.785 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 250}
# 0.798 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 500}
# 0.801 (+/-0.024) for {'max_features': 'log2', 'n_estimators': 750}
# 0.800 (+/-0.022) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.800 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.798 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.84      0.71      0.77      1563
#           1       0.75      0.86      0.80      1560
#
# avg / total       0.79      0.78      0.78      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.772 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 250}
# 0.782 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 500}
# 0.778 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 750}
# 0.779 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.781 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.780 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.772 (+/-0.005) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.782 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.778 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.779 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.781 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.780 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.777 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 250}
# 0.788 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 500}
# 0.792 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 750}
# 0.791 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.793 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.791 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.84      0.72      0.77      1563
#           1       0.75      0.86      0.80      1560
#
# avg / total       0.79      0.79      0.79      3123
#
#
# ********** COUNT **********
#
# *************** SVM ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
#
# Grid scores on development set:
#
# 0.832 (+/-0.018) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.834 (+/-0.018) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.852 (+/-0.008) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.870 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.850 (+/-0.019) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.870 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.848 (+/-0.010) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.856 (+/-0.013) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.855 (+/-0.015) for {'kernel': 'linear', 'C': 1}
# 0.840 (+/-0.016) for {'kernel': 'linear', 'C': 10}
# 0.840 (+/-0.016) for {'kernel': 'linear', 'C': 100}
# 0.840 (+/-0.016) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.79      0.86      1563
#           1       0.82      0.95      0.88      1560
#
# avg / total       0.88      0.87      0.87      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
#
# Grid scores on development set:
#
# 0.829 (+/-0.014) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.806 (+/-0.010) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.851 (+/-0.007) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.859 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.849 (+/-0.017) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.866 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.848 (+/-0.009) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.855 (+/-0.014) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.855 (+/-0.016) for {'kernel': 'linear', 'C': 1}
# 0.839 (+/-0.016) for {'kernel': 'linear', 'C': 10}
# 0.839 (+/-0.016) for {'kernel': 'linear', 'C': 100}
# 0.839 (+/-0.016) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.93      0.87      0.90      1563
#           1       0.88      0.94      0.90      1560
#
# avg / total       0.90      0.90      0.90      3123
#
#
# *************** RF ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.779 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 250}
# 0.782 (+/-0.020) for {'max_features': 'auto', 'n_estimators': 500}
# 0.782 (+/-0.033) for {'max_features': 'auto', 'n_estimators': 750}
# 0.782 (+/-0.028) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.783 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.782 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.779 (+/-0.009) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.782 (+/-0.020) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.782 (+/-0.033) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.782 (+/-0.028) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.783 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.782 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.780 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 250}
# 0.782 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 500}
# 0.783 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 750}
# 0.785 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.786 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.782 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.82      0.69      0.75      1563
#           1       0.73      0.85      0.79      1560
#
# avg / total       0.78      0.77      0.77      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.764 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 250}
# 0.768 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 500}
# 0.768 (+/-0.014) for {'max_features': 'auto', 'n_estimators': 750}
# 0.769 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.770 (+/-0.011) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.769 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.764 (+/-0.009) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.768 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.768 (+/-0.014) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.769 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.770 (+/-0.011) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.769 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.767 (+/-0.004) for {'max_features': 'log2', 'n_estimators': 250}
# 0.769 (+/-0.000) for {'max_features': 'log2', 'n_estimators': 500}
# 0.770 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 750}
# 0.773 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.777 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.771 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.82      0.69      0.75      1563
#           1       0.73      0.85      0.79      1560
#
# avg / total       0.78      0.77      0.77      3123
#
#
# *************************************************
# Running validation on k = 3
#
# Confusion Matrix for Naive Bayes - TFIDF
# [[ 2929.   197.]
#  [  544.  2576.]]
# Accuracy:
# 0.881364073007
#
# Confusion Matrix for Naive Bayes - Count
# [[ 2764.   362.]
#  [  391.  2729.]]
# Accuracy:
# 0.87944284342
#
# ********** TFIDF **********
#
# *************** SVM ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
#
# Grid scores on development set:
#
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.756 (+/-0.004) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.250 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.891 (+/-0.025) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.756 (+/-0.004) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.931 (+/-0.013) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.891 (+/-0.024) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.927 (+/-0.012) for {'kernel': 'linear', 'C': 1}
# 0.929 (+/-0.010) for {'kernel': 'linear', 'C': 10}
# 0.921 (+/-0.022) for {'kernel': 'linear', 'C': 100}
# 0.921 (+/-0.022) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.92      0.93      1563
#           1       0.92      0.94      0.93      1560
#
# avg / total       0.93      0.93      0.93      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
#
# Grid scores on development set:
#
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.522 (+/-0.015) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.884 (+/-0.032) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.523 (+/-0.015) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.931 (+/-0.013) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.884 (+/-0.031) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.926 (+/-0.013) for {'kernel': 'linear', 'C': 1}
# 0.929 (+/-0.011) for {'kernel': 'linear', 'C': 10}
# 0.920 (+/-0.024) for {'kernel': 'linear', 'C': 100}
# 0.920 (+/-0.024) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.92      0.93      1563
#           1       0.92      0.94      0.93      1560
#
# avg / total       0.93      0.93      0.93      3123
#
#
# *************** RF ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1000}
#
# Grid scores on development set:
#
# 0.803 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 250}
# 0.807 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 500}
# 0.801 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 750}
# 0.801 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.803 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.802 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.803 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.807 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.801 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.801 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.803 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.802 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.794 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 250}
# 0.800 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 500}
# 0.803 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 750}
# 0.809 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.808 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.804 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.84      0.72      0.77      1563
#           1       0.75      0.86      0.80      1560
#
# avg / total       0.80      0.79      0.79      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.786 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 250}
# 0.791 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 500}
# 0.784 (+/-0.011) for {'max_features': 'auto', 'n_estimators': 750}
# 0.784 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.787 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.786 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.786 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.791 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.784 (+/-0.011) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.784 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.787 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.786 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.786 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 250}
# 0.792 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 500}
# 0.795 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 750}
# 0.799 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.800 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.796 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.84      0.72      0.77      1563
#           1       0.75      0.86      0.80      1560
#
# avg / total       0.79      0.79      0.79      3123
#
#
# ********** COUNT **********
#
# *************** SVM ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
#
# Grid scores on development set:
#
# 0.846 (+/-0.018) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.845 (+/-0.008) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.868 (+/-0.022) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.875 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.864 (+/-0.015) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.882 (+/-0.009) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.857 (+/-0.030) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.864 (+/-0.013) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.862 (+/-0.003) for {'kernel': 'linear', 'C': 1}
# 0.846 (+/-0.023) for {'kernel': 'linear', 'C': 10}
# 0.845 (+/-0.023) for {'kernel': 'linear', 'C': 100}
# 0.845 (+/-0.023) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.93      0.87      0.90      1563
#           1       0.88      0.94      0.90      1560
#
# avg / total       0.90      0.90      0.90      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
#
# Grid scores on development set:
#
# 0.843 (+/-0.019) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.820 (+/-0.014) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.868 (+/-0.022) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.865 (+/-0.009) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.864 (+/-0.015) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.879 (+/-0.009) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.857 (+/-0.030) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.863 (+/-0.013) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.861 (+/-0.003) for {'kernel': 'linear', 'C': 1}
# 0.846 (+/-0.023) for {'kernel': 'linear', 'C': 10}
# 0.845 (+/-0.023) for {'kernel': 'linear', 'C': 100}
# 0.845 (+/-0.023) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.93      0.87      0.90      1563
#           1       0.88      0.94      0.90      1560
#
# avg / total       0.90      0.90      0.90      3123
#
#
# *************** RF ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'auto', 'n_estimators': 250}
#
# Grid scores on development set:
#
# 0.794 (+/-0.017) for {'max_features': 'auto', 'n_estimators': 250}
# 0.792 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 500}
# 0.792 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 750}
# 0.791 (+/-0.020) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.789 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.786 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.794 (+/-0.017) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.792 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.792 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.791 (+/-0.020) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.789 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.786 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.782 (+/-0.027) for {'max_features': 'log2', 'n_estimators': 250}
# 0.786 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 500}
# 0.787 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 750}
# 0.791 (+/-0.030) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.794 (+/-0.024) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.791 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.84      0.65      0.73      1563
#           1       0.71      0.87      0.79      1560
#
# avg / total       0.78      0.76      0.76      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.778 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 250}
# 0.779 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 500}
# 0.777 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 750}
# 0.777 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.776 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.772 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.778 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.779 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.777 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.777 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.776 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.772 (+/-0.009) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.769 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 250}
# 0.775 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 500}
# 0.776 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 750}
# 0.779 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.783 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.780 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.82      0.69      0.75      1563
#           1       0.73      0.85      0.79      1560
#
# avg / total       0.78      0.77      0.77      3123
#
#
# *************************************************
# Running validation on k = 10
#
# Confusion Matrix for Naive Bayes - TFIDF
# [[ 2930.   196.]
#  [  496.  2624.]]
# Accuracy:
# 0.88920909382
#
# Confusion Matrix for Naive Bayes - Count
# [[ 2790.   336.]
#  [  379.  2741.]]
# Accuracy:
# 0.885526737112
#
# ********** TFIDF **********
#
# *************** SVM ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
#
# Grid scores on development set:
#
# 0.250 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.250 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.842 (+/-0.037) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.250 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.902 (+/-0.031) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.842 (+/-0.037) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.935 (+/-0.026) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.902 (+/-0.031) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.933 (+/-0.027) for {'kernel': 'linear', 'C': 1}
# 0.932 (+/-0.030) for {'kernel': 'linear', 'C': 10}
# 0.929 (+/-0.025) for {'kernel': 'linear', 'C': 100}
# 0.929 (+/-0.025) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.92      0.93      1563
#           1       0.92      0.94      0.93      1560
#
# avg / total       0.93      0.93      0.93      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
#
# Grid scores on development set:
#
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.839 (+/-0.037) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.896 (+/-0.039) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.839 (+/-0.038) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.934 (+/-0.027) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.896 (+/-0.039) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.932 (+/-0.028) for {'kernel': 'linear', 'C': 1}
# 0.932 (+/-0.030) for {'kernel': 'linear', 'C': 10}
# 0.928 (+/-0.025) for {'kernel': 'linear', 'C': 100}
# 0.928 (+/-0.025) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.92      0.93      1563
#           1       0.92      0.94      0.93      1560
#
# avg / total       0.93      0.93      0.93      3123
#
#
# *************** RF ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1000}
#
# Grid scores on development set:
#
# 0.808 (+/-0.044) for {'max_features': 'auto', 'n_estimators': 250}
# 0.799 (+/-0.043) for {'max_features': 'auto', 'n_estimators': 500}
# 0.799 (+/-0.041) for {'max_features': 'auto', 'n_estimators': 750}
# 0.799 (+/-0.039) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.800 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.800 (+/-0.031) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.808 (+/-0.044) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.799 (+/-0.043) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.799 (+/-0.041) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.799 (+/-0.039) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.800 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.800 (+/-0.031) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.793 (+/-0.040) for {'max_features': 'log2', 'n_estimators': 250}
# 0.805 (+/-0.042) for {'max_features': 'log2', 'n_estimators': 500}
# 0.811 (+/-0.033) for {'max_features': 'log2', 'n_estimators': 750}
# 0.815 (+/-0.037) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.813 (+/-0.037) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.810 (+/-0.035) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.84      0.72      0.77      1563
#           1       0.75      0.86      0.80      1560
#
# avg / total       0.80      0.79      0.79      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1000}
#
# Grid scores on development set:
#
# 0.792 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 250}
# 0.784 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 500}
# 0.783 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 750}
# 0.784 (+/-0.031) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.784 (+/-0.029) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.783 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.792 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.784 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.783 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.784 (+/-0.031) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.784 (+/-0.029) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.783 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.786 (+/-0.036) for {'max_features': 'log2', 'n_estimators': 250}
# 0.797 (+/-0.036) for {'max_features': 'log2', 'n_estimators': 500}
# 0.803 (+/-0.030) for {'max_features': 'log2', 'n_estimators': 750}
# 0.807 (+/-0.035) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.806 (+/-0.035) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.803 (+/-0.034) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.84      0.72      0.77      1563
#           1       0.75      0.86      0.80      1560
#
# avg / total       0.80      0.79      0.79      3123
#
#
# ********** COUNT **********
#
# *************** SVM ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
#
# Grid scores on development set:
#
# 0.857 (+/-0.037) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.854 (+/-0.028) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.880 (+/-0.039) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.886 (+/-0.032) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.870 (+/-0.029) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.894 (+/-0.030) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.867 (+/-0.040) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.874 (+/-0.029) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.874 (+/-0.026) for {'kernel': 'linear', 'C': 1}
# 0.861 (+/-0.025) for {'kernel': 'linear', 'C': 10}
# 0.857 (+/-0.025) for {'kernel': 'linear', 'C': 100}
# 0.857 (+/-0.025) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.93      0.87      0.90      1563
#           1       0.88      0.94      0.90      1560
#
# avg / total       0.90      0.90      0.90      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
#
# Grid scores on development set:
#
# 0.854 (+/-0.038) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.832 (+/-0.031) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.880 (+/-0.038) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.877 (+/-0.034) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.870 (+/-0.029) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.891 (+/-0.031) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.866 (+/-0.041) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.873 (+/-0.029) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.874 (+/-0.026) for {'kernel': 'linear', 'C': 1}
# 0.860 (+/-0.026) for {'kernel': 'linear', 'C': 10}
# 0.857 (+/-0.025) for {'kernel': 'linear', 'C': 100}
# 0.857 (+/-0.025) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.93      0.87      0.90      1563
#           1       0.88      0.94      0.90      1560
#
# avg / total       0.90      0.90      0.90      3123
#
#
# *************** RF ***************
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1000}
#
# Grid scores on development set:
#
# 0.792 (+/-0.041) for {'max_features': 'auto', 'n_estimators': 250}
# 0.791 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 500}
# 0.788 (+/-0.040) for {'max_features': 'auto', 'n_estimators': 750}
# 0.786 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.791 (+/-0.034) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.788 (+/-0.033) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.792 (+/-0.041) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.791 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.788 (+/-0.040) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.786 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.791 (+/-0.034) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.788 (+/-0.033) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.787 (+/-0.032) for {'max_features': 'log2', 'n_estimators': 250}
# 0.792 (+/-0.038) for {'max_features': 'log2', 'n_estimators': 500}
# 0.792 (+/-0.036) for {'max_features': 'log2', 'n_estimators': 750}
# 0.794 (+/-0.038) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.793 (+/-0.035) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.793 (+/-0.040) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.82      0.68      0.75      1563
#           1       0.73      0.85      0.78      1560
#
# avg / total       0.77      0.77      0.76      3123
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.777 (+/-0.041) for {'max_features': 'auto', 'n_estimators': 250}
# 0.777 (+/-0.034) for {'max_features': 'auto', 'n_estimators': 500}
# 0.774 (+/-0.038) for {'max_features': 'auto', 'n_estimators': 750}
# 0.772 (+/-0.038) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.777 (+/-0.032) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.773 (+/-0.033) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.777 (+/-0.041) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.777 (+/-0.034) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.774 (+/-0.038) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.772 (+/-0.038) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.777 (+/-0.032) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.773 (+/-0.033) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.777 (+/-0.024) for {'max_features': 'log2', 'n_estimators': 250}
# 0.781 (+/-0.034) for {'max_features': 'log2', 'n_estimators': 500}
# 0.782 (+/-0.033) for {'max_features': 'log2', 'n_estimators': 750}
# 0.784 (+/-0.033) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.784 (+/-0.033) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.783 (+/-0.038) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.82      0.69      0.75      1563
#           1       0.73      0.85      0.79      1560
#
# avg / total       0.78      0.77      0.77      3123

# %%
rfc = RandomForestClassifier(max_depth=2, random_state=0)
#RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2']
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X, y)
print CV_rfc.best_params_

# %%
kvalues = [2,3,10]
count = float(len(data))

for k in kvalues:

    print ("*************************************************")
    print ("Running validation on k = " + str(k))
    print ()
    
    kf = StratifiedKFold(n_splits=k)
    
    X_train, X_test, y_train, y_test = train_test_split(
        data, labels, test_size=0.5, random_state=0)
    
    print ("*************** Random Forests Grid Search ***************")
    print ()
    print ("********** TFIDF **********")
    print ()
    
    tfidfVectorizer = TfidfVectorizer(min_df=5,
                                     max_df = 0.8,
                                     sublinear_tf=True,
                                     use_idf=True,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    X_train_tfidf = tfidfVectorizer.fit_transform(X_train) 
    X_test_tfidf = tfidfVectorizer.transform(X_test)
    
    #trainSVM(k, X_train_tfidf, X_test_tfidf, y_train, y_test)
    rfc = RandomForestClassifier(max_depth=2, random_state=0)
    #RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

    param_grid = { 
        'n_estimators': [250, 500, 750, 1000, 1250, 1500],
        'max_features': ['auto', 'sqrt', 'log2']
    }
    
    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters %s" % score)
        print()

        clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=k,
                           scoring='%s_macro' % score)
        clf.fit(X_train_tfidf, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test_tfidf)
        print(classification_report(y_true, y_pred))
        print()


    print ("********** COUNT **********")
    print ()
    
    countVectorizer = CountVectorizer(min_df=5,
                                     max_df = 0.8,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    X_train_count = countVectorizer.fit_transform(X_train)
    X_test_count = countVectorizer.transform(X_test)
    
    rfc = RandomForestClassifier(max_depth=2, random_state=0)
    #RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

    param_grid = { 
        #"n_estimators" : [9, 18, 27, 36, 45, 54, 63],
        #"max_depth" : [1, 5, 10, 15, 20, 25, 30],
        #"min_samples_leaf" : [1, 2, 4, 6, 8, 10],
        'n_estimators': [250, 500, 750, 1000, 1250, 1500],
        'max_features': ['auto', 'sqrt', 'log2'],
    }

    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters %s" % score)
        print()

        clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=k,
                           scoring='%s_macro' % score)
        clf.fit(X_train_tfidf, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test_tfidf)
        print(classification_report(y_true, y_pred))
        print()
# Out:
# *************************************************
# Running validation on k = 2
#
# *************** Random Forests Grid Search ***************
#
# ********** TFIDF **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.801 (+/-0.017) for {'max_features': 'auto', 'n_estimators': 250}
# 0.801 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 500}
# 0.802 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 750}
# 0.799 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.799 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.797 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.801 (+/-0.017) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.801 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.802 (+/-0.005) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.799 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.799 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.797 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.802 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 250}
# 0.819 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 500}
# 0.815 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 750}
# 0.818 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.821 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.821 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 500}
#
# Grid scores on development set:
#
# 0.781 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 250}
# 0.781 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 500}
# 0.781 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 750}
# 0.779 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.779 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.778 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.781 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.781 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.781 (+/-0.000) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.779 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.779 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.778 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.779 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 250}
# 0.794 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 500}
# 0.789 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 750}
# 0.790 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.793 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.793 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.90      0.65      0.75      1573
#           1       0.72      0.93      0.81      1555
#
# avg / total       0.81      0.79      0.78      3128
#
#
# ********** COUNT **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.801 (+/-0.017) for {'max_features': 'auto', 'n_estimators': 250}
# 0.801 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 500}
# 0.802 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 750}
# 0.799 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.799 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.797 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.801 (+/-0.017) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.801 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.802 (+/-0.005) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.799 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.799 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.797 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.802 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 250}
# 0.819 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 500}
# 0.815 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 750}
# 0.818 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.821 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.821 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 500}
#
# Grid scores on development set:
#
# 0.781 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 250}
# 0.781 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 500}
# 0.781 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 750}
# 0.779 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.779 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.778 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.781 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.781 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.781 (+/-0.000) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.779 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.779 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.778 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.779 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 250}
# 0.794 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 500}
# 0.789 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 750}
# 0.790 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.793 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.793 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.90      0.65      0.75      1573
#           1       0.72      0.93      0.81      1555
#
# avg / total       0.81      0.79      0.78      3128
#
#
# *************************************************
# Running validation on k = 3
#
# *************** Random Forests Grid Search ***************
#
# ********** TFIDF **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.803 (+/-0.014) for {'max_features': 'auto', 'n_estimators': 250}
# 0.806 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 500}
# 0.800 (+/-0.029) for {'max_features': 'auto', 'n_estimators': 750}
# 0.804 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.803 (+/-0.023) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.802 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.803 (+/-0.014) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.806 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.800 (+/-0.029) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.804 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.803 (+/-0.023) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.802 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.790 (+/-0.026) for {'max_features': 'log2', 'n_estimators': 250}
# 0.808 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 500}
# 0.808 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 750}
# 0.812 (+/-0.018) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.819 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.818 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.779 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 250}
# 0.783 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 500}
# 0.780 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 750}
# 0.783 (+/-0.022) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.781 (+/-0.020) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.781 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.779 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.783 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.780 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.783 (+/-0.022) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.781 (+/-0.020) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.781 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.766 (+/-0.028) for {'max_features': 'log2', 'n_estimators': 250}
# 0.780 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 500}
# 0.782 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 750}
# 0.786 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.792 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.791 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# ********** COUNT **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.803 (+/-0.014) for {'max_features': 'auto', 'n_estimators': 250}
# 0.806 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 500}
# 0.800 (+/-0.029) for {'max_features': 'auto', 'n_estimators': 750}
# 0.804 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.803 (+/-0.023) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.802 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.803 (+/-0.014) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.806 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.800 (+/-0.029) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.804 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.803 (+/-0.023) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.802 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.790 (+/-0.026) for {'max_features': 'log2', 'n_estimators': 250}
# 0.808 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 500}
# 0.808 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 750}
# 0.812 (+/-0.018) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.819 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.818 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.779 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 250}
# 0.783 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 500}
# 0.780 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 750}
# 0.783 (+/-0.022) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.781 (+/-0.020) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.781 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.779 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.783 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.780 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.783 (+/-0.022) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.781 (+/-0.020) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.781 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.766 (+/-0.028) for {'max_features': 'log2', 'n_estimators': 250}
# 0.780 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 500}
# 0.782 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 750}
# 0.786 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.792 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.791 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# *************************************************
# Running validation on k = 10
#
# *************** Random Forests Grid Search ***************
#
# ********** TFIDF **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.801 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 250}
# 0.812 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 500}
# 0.805 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 750}
# 0.805 (+/-0.041) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.802 (+/-0.039) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.803 (+/-0.038) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.801 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.812 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.805 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.805 (+/-0.041) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.802 (+/-0.039) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.803 (+/-0.038) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.788 (+/-0.049) for {'max_features': 'log2', 'n_estimators': 250}
# 0.809 (+/-0.042) for {'max_features': 'log2', 'n_estimators': 500}
# 0.811 (+/-0.053) for {'max_features': 'log2', 'n_estimators': 750}
# 0.817 (+/-0.051) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.821 (+/-0.041) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.817 (+/-0.041) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.781 (+/-0.034) for {'max_features': 'auto', 'n_estimators': 250}
# 0.790 (+/-0.032) for {'max_features': 'auto', 'n_estimators': 500}
# 0.784 (+/-0.033) for {'max_features': 'auto', 'n_estimators': 750}
# 0.783 (+/-0.040) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.780 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.782 (+/-0.035) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.781 (+/-0.034) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.790 (+/-0.032) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.784 (+/-0.033) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.783 (+/-0.040) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.780 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.782 (+/-0.035) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.765 (+/-0.052) for {'max_features': 'log2', 'n_estimators': 250}
# 0.780 (+/-0.037) for {'max_features': 'log2', 'n_estimators': 500}
# 0.785 (+/-0.053) for {'max_features': 'log2', 'n_estimators': 750}
# 0.790 (+/-0.054) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.792 (+/-0.044) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.789 (+/-0.041) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# ********** COUNT **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.801 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 250}
# 0.812 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 500}
# 0.805 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 750}
# 0.805 (+/-0.041) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.802 (+/-0.039) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.803 (+/-0.038) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.801 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.812 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.805 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.805 (+/-0.041) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.802 (+/-0.039) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.803 (+/-0.038) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.788 (+/-0.049) for {'max_features': 'log2', 'n_estimators': 250}
# 0.809 (+/-0.042) for {'max_features': 'log2', 'n_estimators': 500}
# 0.811 (+/-0.053) for {'max_features': 'log2', 'n_estimators': 750}
# 0.817 (+/-0.051) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.821 (+/-0.041) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.817 (+/-0.041) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 1250}
#
# Grid scores on development set:
#
# 0.781 (+/-0.034) for {'max_features': 'auto', 'n_estimators': 250}
# 0.790 (+/-0.032) for {'max_features': 'auto', 'n_estimators': 500}
# 0.784 (+/-0.033) for {'max_features': 'auto', 'n_estimators': 750}
# 0.783 (+/-0.040) for {'max_features': 'auto', 'n_estimators': 1000}
# 0.780 (+/-0.036) for {'max_features': 'auto', 'n_estimators': 1250}
# 0.782 (+/-0.035) for {'max_features': 'auto', 'n_estimators': 1500}
# 0.781 (+/-0.034) for {'max_features': 'sqrt', 'n_estimators': 250}
# 0.790 (+/-0.032) for {'max_features': 'sqrt', 'n_estimators': 500}
# 0.784 (+/-0.033) for {'max_features': 'sqrt', 'n_estimators': 750}
# 0.783 (+/-0.040) for {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.780 (+/-0.036) for {'max_features': 'sqrt', 'n_estimators': 1250}
# 0.782 (+/-0.035) for {'max_features': 'sqrt', 'n_estimators': 1500}
# 0.765 (+/-0.052) for {'max_features': 'log2', 'n_estimators': 250}
# 0.780 (+/-0.037) for {'max_features': 'log2', 'n_estimators': 500}
# 0.785 (+/-0.053) for {'max_features': 'log2', 'n_estimators': 750}
# 0.790 (+/-0.054) for {'max_features': 'log2', 'n_estimators': 1000}
# 0.792 (+/-0.044) for {'max_features': 'log2', 'n_estimators': 1250}
# 0.789 (+/-0.041) for {'max_features': 'log2', 'n_estimators': 1500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76      1573
#           1       0.73      0.93      0.82      1555
#
# avg / total       0.82      0.79      0.79      3128
