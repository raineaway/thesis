# %% [markdown]
# # Stratified k-Fold Cross Validation
#
# ### Vectorizers:
# TFIDF, Token Count
#
# ### Machine Learning Models:
# SVM (linear)
# SVM (RBF)
# Naive Bayes
#
#
# ### Description
# These feature extraction methods and machine learning models are combined and ran using k-fold cross validation, with values of k = 2, 3, and 10. Feature statistics are also extracted for further analysis.

# %% [markdown]
# Import the required packages.

# %%
import os
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC, SVC
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import pandas as pd
import pprint
from ast import literal_eval

from __future__ import print_function


def train(k, data, labels):
    
    kf = StratifiedKFold(n_splits=k)
    
    totalNB_tfidf = 0       # Accuracy measure
    totalMatNB_tfidf = np.zeros((2,2));        # Confusion matrix
    totalNB_count = 0       # Accuracy measure
    totalMatNB_count = np.zeros((2,2));        # Confusion matrix
    
    totalRF_tfidf = 0
    totalMatRF_tfidf = np.zeros((2,2));
    totalRF_count = 0
    totalMatRF_count = np.zeros((2,2));
    
    for train_index, test_index in kf.split(data,labels):
        X_train = [data[i] for i in train_index]
        X_test = [data[i] for i in test_index]
        y_train = [labels[i] for i in train_index]
        y_test = [labels[i] for i in test_index]
        
        print ()
        print ("Number of fake and real samples: ", y_train.count(1), ", ", y_train.count(0))
        print ("Number of fake and real tests: ", y_test.count(1), ",", y_test.count(0))
        print ()
        
        tfidfVectorizer = TfidfVectorizer(min_df=5,
                                     max_df = 0.8,
                                     sublinear_tf=True,
                                     use_idf=True,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
        
        countVectorizer = CountVectorizer(min_df=5,
                                     max_df = 0.8,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')

        X_train_tfidf = tfidfVectorizer.fit_transform(X_train) 
        X_test_tfidf = tfidfVectorizer.transform(X_test)
        
        X_train_count = countVectorizer.fit_transform(X_train)
        X_test_count = countVectorizer.transform(X_test)
        
        nbModel = MultinomialNB() 
        nbModel.fit(X_train_tfidf, y_train)
        nbResult = nbModel.predict(X_test_tfidf)
        totalMatNB_tfidf = totalMatNB_tfidf + confusion_matrix(y_test, nbResult)
        totalNB_tfidf = totalNB_tfidf+sum(y_test==nbResult)
        
        rfModel = RandomForestClassifier(max_depth=2, random_state=0)
        rfModel.fit(X_train_tfidf, y_train)
        rfResult = rfModel.predict(X_test_tfidf)
        totalMatRF_tfidf = totalMatRF_tfidf + confusion_matrix(y_test, rfResult)
        totalRF_tfidf = totalRF_tfidf+sum(y_test==rfResult)
        
        nbModel = MultinomialNB() 
        nbModel.fit(X_train_count, y_train)
        nbResult = nbModel.predict(X_test_count)
        totalMatNB_count = totalMatNB_count + confusion_matrix(y_test, nbResult)
        totalNB_count = totalNB_count+sum(y_test==nbResult)
        
        rfModel = RandomForestClassifier(max_depth=2, random_state=0)
        rfModel.fit(X_train_count, y_train)
        rfResult = rfModel.predict(X_test_count)
        totalMatRF_count = totalMatRF_count + confusion_matrix(y_test, rfResult)
        totalRF_count = totalRF_count+sum(y_test==rfResult)
    
    print("Confusion Matrix for Naive Bayes - TFIDF")
    print(totalMatNB_tfidf)
    print("Accuracy: ")
    print(totalNB_tfidf/count)
    print ()
    
    print("Confusion Matrix for Naive Bayes - Count")
    print(totalMatNB_count)
    print("Accuracy: ")
    print(totalNB_count/count)
    print ()

    
    print("Confusion Matrix for Random Forests - TFIDF")
    print(totalMatRF_tfidf)
    print("Accuracy: ")
    print(totalRF_tfidf/count)
    print ()
    
    print("Confusion Matrix for Random Forests - Count")
    print(totalMatRF_count)
    print("Accuracy: ")
    print(totalRF_count/count)
    print ()


def trainSVM(k, X_train, X_test, y_train, y_test):
    
    tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters %s" % score)
        print()

        clf = GridSearchCV(SVC(), tuned_parameters, cv=k,
                           scoring='%s_macro' % score)
        clf.fit(X_train, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test)
        print(classification_report(y_true, y_pred))
        print()

# %% [markdown]
# Read the dataset, and create the data and label arrays.

# %%
corpus = pd.read_csv('gm_fake_or_real_equal.csv');

data = []
labels = []
for news in corpus['text']:
    data.append(news)

for news in corpus['class']:
    labels.append(news)

print ("Total number of articles: " + str(len(data)))
# Out:
# Total number of articles: 6256

# %% [markdown]
# ## Training and Validation

# %%
#Stratified 10-cross fold validation with SVM and Multinomial NB 
      
kvalues = [10]
count = float(len(data))

for k in kvalues:

    print ("*************************************************")
    print ("Running validation on k = " + str(k))
    print ()
    
    kf = StratifiedKFold(n_splits=k)
    
    
    #Naive Bayes
     
    train(k, data, labels)
    
    
    #SVM
    
    X_train, X_test, y_train, y_test = train_test_split(
        data, labels, test_size=0.5, random_state=0)
    
    print ("*************** SVM ***************")
    print ()
    #print ("********** TFIDF **********")
    #print ()
    
    #tfidfVectorizer = TfidfVectorizer(min_df=5,
    #                                 max_df = 0.8,
    #                                 sublinear_tf=True,
    #                                 use_idf=True,
    #                                 stop_words='english',
    #                                 token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    #X_train_tfidf = tfidfVectorizer.fit_transform(X_train) 
    #X_test_tfidf = tfidfVectorizer.transform(X_test)
    
    #trainSVM(k, X_train_tfidf, X_test_tfidf, y_train, y_test)
    
    
    print ("********** COUNT **********")
    print ()
    
    countVectorizer = CountVectorizer(min_df=5,
                                     max_df = 0.8,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    X_train_count = countVectorizer.fit_transform(X_train)
    X_test_count = countVectorizer.transform(X_test)
    
    trainSVM(k, X_train_count, X_test_count, y_train, y_test)
# Out:
# *************************************************
# Running validation on k = 10
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2815 ,  2815
# Number of fake and real tests:  313 , 313
#
#
# Number of fake and real samples:  2816 ,  2816
# Number of fake and real tests:  312 , 312
#
#
# Number of fake and real samples:  2816 ,  2816
# Number of fake and real tests:  312 , 312
#
# Confusion Matrix for Naive Bayes - TFIDF
# [[ 2932.   196.]
#  [  497.  2631.]]
# Accuracy:
# 0.889226342711
#
# Confusion Matrix for Naive Bayes - Count
# [[ 2795.   333.]
#  [  382.  2746.]]
# Accuracy:
# 0.88570971867
#
# Confusion Matrix for Random Forests - TFIDF
# [[ 1888.  1240.]
#  [  535.  2593.]]
# Accuracy:
# 0.716272378517
#
# Confusion Matrix for Random Forests - Count
# [[ 1886.  1242.]
#  [  563.  2565.]]
# Accuracy:
# 0.711476982097
#
# *************** SVM ***************
#
# ********** COUNT **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
#
# Grid scores on development set:
#
# 0.856 (+/-0.040) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.847 (+/-0.035) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.882 (+/-0.044) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.877 (+/-0.030) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.870 (+/-0.032) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.899 (+/-0.038) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.870 (+/-0.034) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.881 (+/-0.045) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.878 (+/-0.036) for {'kernel': 'linear', 'C': 1}
# 0.854 (+/-0.029) for {'kernel': 'linear', 'C': 10}
# 0.853 (+/-0.032) for {'kernel': 'linear', 'C': 100}
# 0.853 (+/-0.032) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.92      0.87      0.89      1573
#           1       0.88      0.92      0.90      1555
#
# avg / total       0.90      0.90      0.90      3128
#
#
# # Tuning hyper-parameters recall

# %%
rfc = RandomForestClassifier(max_depth=2, random_state=0)
#RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2']
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X, y)
print CV_rfc.best_params_

# %%
kvalues = [2,3,10]
count = float(len(data))

for k in kvalues:

    print ("*************************************************")
    print ("Running validation on k = " + str(k))
    print ()
    
    kf = StratifiedKFold(n_splits=k)
    
    X_train, X_test, y_train, y_test = train_test_split(
        data, labels, test_size=0.5, random_state=0)
    
    print ("*************** Random Forests Grid Search ***************")
    print ()
    print ("********** TFIDF **********")
    print ()
    
    tfidfVectorizer = TfidfVectorizer(min_df=5,
                                     max_df = 0.8,
                                     sublinear_tf=True,
                                     use_idf=True,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    X_train_tfidf = tfidfVectorizer.fit_transform(X_train) 
    X_test_tfidf = tfidfVectorizer.transform(X_test)
    
    #trainSVM(k, X_train_tfidf, X_test_tfidf, y_train, y_test)
    rfc = RandomForestClassifier(max_depth=2, random_state=0)
    #RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

    param_grid = { 
        'n_estimators': [200, 700],
        'max_features': ['auto', 'sqrt', 'log2']
    }
    
    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters %s" % score)
        print()

        clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=k,
                           scoring='%s_macro' % score)
        clf.fit(X_train_tfidf, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test_tfidf)
        print(classification_report(y_true, y_pred))
        print()


    print ("********** COUNT **********")
    print ()
    
    countVectorizer = CountVectorizer(min_df=5,
                                     max_df = 0.8,
                                     stop_words='english',
                                     token_pattern=ur'(?u)\b[^\W\d][^\W\d]+\b')
    
    X_train_count = countVectorizer.fit_transform(X_train)
    X_test_count = countVectorizer.transform(X_test)
    
    rfc = RandomForestClassifier(max_depth=2, random_state=0)
    #RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

    param_grid = { 
        "n_estimators" : [9, 18, 27, 36, 45, 54, 63],
        "max_depth" : [1, 5, 10, 15, 20, 25, 30],
        "min_samples_leaf" : [1, 2, 4, 6, 8, 10],
        #'n_estimators': [200, 700],
        'max_features': ['auto', 'sqrt', 'log2']
    }

    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters %s" % score)
        print()

        clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=k,
                           scoring='%s_macro' % score)
        clf.fit(X_train_tfidf, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test_tfidf)
        print(classification_report(y_true, y_pred))
        print()
# Out:
# *************************************************
# Running validation on k = 2
#
# *************** Random Forests Grid Search ***************
#
# ********** TFIDF **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 700}
#
# Grid scores on development set:
#
# 0.800 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 200}
# 0.801 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 700}
# 0.800 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 200}
# 0.801 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 700}
# 0.789 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 200}
# 0.815 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 700}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.90      0.64      0.75      1573
#           1       0.72      0.93      0.81      1555
#
# avg / total       0.81      0.78      0.78      3128
#
#
# # Tuning hyper-parameters recall
#
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 700}
#
# Grid scores on development set:
#
# 0.780 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 200}
# 0.780 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 700}
# 0.780 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 200}
# 0.780 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 700}
# 0.774 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 200}
# 0.787 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 700}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.90      0.64      0.75      1573
#           1       0.72      0.93      0.81      1555
#
# avg / total       0.81      0.78      0.78      3128
#
#
# ********** COUNT **********
#
# # Tuning hyper-parameters precision
#
# Best parameters set found on development set:
#
# {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 1}
#
# Grid scores on development set:
#
# 0.673 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.743 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.755 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.762 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.774 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.774 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.778 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.673 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.743 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.755 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.762 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.774 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.774 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.778 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.673 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.743 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.755 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.762 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.774 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.774 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.778 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.673 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.743 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.755 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.762 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.774 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.774 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.778 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.673 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.743 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.755 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.762 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.774 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.774 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.778 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.673 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.743 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.755 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.762 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.774 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.774 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.778 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.673 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.743 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.755 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.762 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.774 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.774 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.778 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.673 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.743 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.755 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.762 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.774 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.774 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.778 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.673 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.743 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.755 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.762 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.774 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.774 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.778 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.673 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.743 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.755 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.762 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.774 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.774 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.778 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.673 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.743 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.755 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.762 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.774 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.774 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.778 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.673 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.743 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.755 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.762 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.774 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.774 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.778 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.592 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.634 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.635 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.671 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.687 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.696 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.700 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 1}
# 0.592 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.634 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.635 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.671 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.687 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.696 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.700 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 2}
# 0.592 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.634 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.636 (+/-0.004) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.672 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.688 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.697 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.704 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 4}
# 0.588 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.633 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.637 (+/-0.005) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.673 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.687 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.696 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.702 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 6}
# 0.589 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.631 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.638 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.673 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.685 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.696 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.701 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 8}
# 0.597 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.631 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.638 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.678 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.688 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.698 (+/-0.018) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.706 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 10}
# 0.761 (+/-0.028) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.796 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.801 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.803 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.804 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.807 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.807 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.759 (+/-0.011) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.783 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.796 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.801 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.802 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.807 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.811 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.771 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.795 (+/-0.011) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.794 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.800 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.809 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.806 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.812 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.760 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.788 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.794 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.805 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.807 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.805 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.806 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.761 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.787 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.793 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.795 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.806 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.805 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.812 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.761 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.786 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.797 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.797 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.804 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.808 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.809 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.761 (+/-0.028) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.796 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.801 (+/-0.005) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.803 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.804 (+/-0.000) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.807 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.807 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.759 (+/-0.011) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.783 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.796 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.801 (+/-0.000) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.802 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.807 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.811 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.771 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.795 (+/-0.011) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.794 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.800 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.809 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.806 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.812 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.760 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.788 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.794 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.805 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.807 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.805 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.806 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.761 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.787 (+/-0.009) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.793 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.795 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.806 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.805 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.812 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.761 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.786 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.797 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.797 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.804 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.808 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.809 (+/-0.000) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.675 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.718 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.734 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.747 (+/-0.029) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.753 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.760 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.758 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 1}
# 0.675 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.722 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.739 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.741 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.748 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.762 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.760 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 2}
# 0.674 (+/-0.018) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.719 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.734 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.739 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.747 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.760 (+/-0.000) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.763 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 4}
# 0.670 (+/-0.005) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.714 (+/-0.004) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.730 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.740 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.743 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.759 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.761 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 6}
# 0.686 (+/-0.028) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.724 (+/-0.027) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.735 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.739 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.741 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.758 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.763 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 8}
# 0.684 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.725 (+/-0.021) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.736 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.742 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.746 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.758 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.757 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 5, 'min_samples_leaf': 10}
# 0.780 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.808 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.818 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.822 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.826 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.828 (+/-0.023) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.830 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.779 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.811 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.823 (+/-0.017) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.825 (+/-0.038) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.829 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.831 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.833 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.780 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.799 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.816 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.817 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.817 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.822 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.823 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.795 (+/-0.034) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.806 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.817 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.819 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.819 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.828 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.832 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.786 (+/-0.030) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.807 (+/-0.014) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.815 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.825 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.826 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.830 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.827 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.782 (+/-0.029) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.800 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.816 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.818 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.819 (+/-0.011) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.822 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.825 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.780 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.808 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.818 (+/-0.005) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.822 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.826 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.828 (+/-0.023) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.830 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.779 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.811 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.823 (+/-0.017) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.825 (+/-0.038) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.829 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.831 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.833 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.780 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.799 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.816 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.817 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.817 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.822 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.823 (+/-0.000) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.795 (+/-0.034) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.806 (+/-0.006) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.817 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.819 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.819 (+/-0.012) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.828 (+/-0.009) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.832 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.786 (+/-0.030) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.807 (+/-0.014) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.815 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.825 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.826 (+/-0.009) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.830 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.827 (+/-0.000) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.782 (+/-0.029) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.800 (+/-0.012) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.816 (+/-0.008) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.818 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.819 (+/-0.011) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.822 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.825 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.708 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.750 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.763 (+/-0.004) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.770 (+/-0.022) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.779 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.787 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.793 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 1}
# 0.722 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.753 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.775 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.774 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.782 (+/-0.004) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.793 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.793 (+/-0.003) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 2}
# 0.716 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.753 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.763 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.768 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.774 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.784 (+/-0.006) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.790 (+/-0.000) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 4}
# 0.706 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.752 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.768 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.766 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.772 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.788 (+/-0.000) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.789 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 6}
# 0.703 (+/-0.021) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.754 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.772 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.764 (+/-0.005) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.769 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.783 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.784 (+/-0.004) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 8}
# 0.700 (+/-0.044) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.747 (+/-0.015) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.762 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.764 (+/-0.001) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.772 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.783 (+/-0.007) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.782 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 10, 'min_samples_leaf': 10}
# 0.796 (+/-0.022) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.812 (+/-0.010) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.827 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.835 (+/-0.011) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.843 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.842 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.847 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.796 (+/-0.015) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.817 (+/-0.007) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.830 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.831 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.837 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.836 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.845 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.793 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 4}
# 0.817 (+/-0.014) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 4}
# 0.828 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 4}
# 0.836 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 4}
# 0.842 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 4}
# 0.843 (+/-0.001) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 4}
# 0.841 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 4}
# 0.798 (+/-0.022) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 6}
# 0.818 (+/-0.002) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 6}
# 0.822 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 6}
# 0.828 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 6}
# 0.838 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 6}
# 0.839 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 6}
# 0.843 (+/-0.003) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 6}
# 0.791 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 8}
# 0.817 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 8}
# 0.827 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 8}
# 0.839 (+/-0.008) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 8}
# 0.838 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 8}
# 0.836 (+/-0.004) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 8}
# 0.838 (+/-0.009) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 8}
# 0.788 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 10}
# 0.805 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 10}
# 0.817 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 10}
# 0.821 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 10}
# 0.827 (+/-0.006) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 10}
# 0.831 (+/-0.000) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 10}
# 0.836 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 10}
# 0.796 (+/-0.022) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.812 (+/-0.010) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.827 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.835 (+/-0.011) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.843 (+/-0.012) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.842 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.847 (+/-0.001) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 1}
# 0.796 (+/-0.015) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.817 (+/-0.007) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.830 (+/-0.009) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.831 (+/-0.002) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.837 (+/-0.004) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.836 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 15, 'min_samples_leaf': 2}
# 0.845 (+/-0.003) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 15, 'min_samples_leaf': 2}
# ...
# 0.738 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 25, 'min_samples_leaf': 6}
# 0.760 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 25, 'min_samples_leaf': 6}
# 0.766 (+/-0.019) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 25, 'min_samples_leaf': 6}
# 0.777 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 25, 'min_samples_leaf': 6}
# 0.787 (+/-0.022) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 25, 'min_samples_leaf': 6}
# 0.799 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 25, 'min_samples_leaf': 6}
# 0.801 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 25, 'min_samples_leaf': 6}
# 0.736 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 25, 'min_samples_leaf': 8}
# 0.760 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 25, 'min_samples_leaf': 8}
# 0.776 (+/-0.033) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 25, 'min_samples_leaf': 8}
# 0.779 (+/-0.036) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 25, 'min_samples_leaf': 8}
# 0.790 (+/-0.030) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 25, 'min_samples_leaf': 8}
# 0.805 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 25, 'min_samples_leaf': 8}
# 0.806 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 25, 'min_samples_leaf': 8}
# 0.733 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 25, 'min_samples_leaf': 10}
# 0.752 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 25, 'min_samples_leaf': 10}
# 0.767 (+/-0.027) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 25, 'min_samples_leaf': 10}
# 0.771 (+/-0.034) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 25, 'min_samples_leaf': 10}
# 0.785 (+/-0.034) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 25, 'min_samples_leaf': 10}
# 0.794 (+/-0.012) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 25, 'min_samples_leaf': 10}
# 0.799 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 25, 'min_samples_leaf': 10}
# 0.800 (+/-0.022) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.830 (+/-0.022) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.844 (+/-0.025) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.860 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.863 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.860 (+/-0.027) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.867 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.804 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.841 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.846 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.858 (+/-0.031) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.857 (+/-0.032) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.860 (+/-0.037) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.863 (+/-0.031) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.806 (+/-0.030) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.831 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.842 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.856 (+/-0.030) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.859 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.858 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.862 (+/-0.020) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.815 (+/-0.013) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.839 (+/-0.017) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.844 (+/-0.026) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.853 (+/-0.028) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.856 (+/-0.023) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.856 (+/-0.017) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.858 (+/-0.012) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.815 (+/-0.028) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.829 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.848 (+/-0.024) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.847 (+/-0.020) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.844 (+/-0.014) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.850 (+/-0.019) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.850 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.798 (+/-0.020) for {'max_features': 'auto', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.826 (+/-0.005) for {'max_features': 'auto', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.835 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.838 (+/-0.027) for {'max_features': 'auto', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.840 (+/-0.021) for {'max_features': 'auto', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.846 (+/-0.016) for {'max_features': 'auto', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.850 (+/-0.018) for {'max_features': 'auto', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.800 (+/-0.022) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.830 (+/-0.022) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.844 (+/-0.025) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.860 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.863 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.860 (+/-0.027) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.867 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.804 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.841 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.846 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.858 (+/-0.031) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.857 (+/-0.032) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.860 (+/-0.037) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.863 (+/-0.031) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.806 (+/-0.030) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.831 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.842 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.856 (+/-0.030) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.859 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.858 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.862 (+/-0.020) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.815 (+/-0.013) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.839 (+/-0.017) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.844 (+/-0.026) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.853 (+/-0.028) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.856 (+/-0.023) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.856 (+/-0.017) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.858 (+/-0.012) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.815 (+/-0.028) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.829 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.848 (+/-0.024) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.847 (+/-0.020) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.844 (+/-0.014) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.850 (+/-0.019) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.850 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.798 (+/-0.020) for {'max_features': 'sqrt', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.826 (+/-0.005) for {'max_features': 'sqrt', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.835 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.838 (+/-0.027) for {'max_features': 'sqrt', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.840 (+/-0.021) for {'max_features': 'sqrt', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.846 (+/-0.016) for {'max_features': 'sqrt', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.850 (+/-0.018) for {'max_features': 'sqrt', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.741 (+/-0.021) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.768 (+/-0.040) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.787 (+/-0.031) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.788 (+/-0.049) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.802 (+/-0.052) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.814 (+/-0.043) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.815 (+/-0.027) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 1}
# 0.755 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.788 (+/-0.010) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.793 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.796 (+/-0.018) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.804 (+/-0.017) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.817 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.815 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 2}
# 0.749 (+/-0.011) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.767 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.775 (+/-0.026) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.780 (+/-0.021) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.793 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.802 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.808 (+/-0.020) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 4}
# 0.746 (+/-0.004) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.765 (+/-0.021) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.774 (+/-0.032) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.784 (+/-0.030) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.788 (+/-0.027) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.798 (+/-0.018) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.802 (+/-0.016) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 6}
# 0.736 (+/-0.002) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.757 (+/-0.018) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.777 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.784 (+/-0.040) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.790 (+/-0.035) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.809 (+/-0.021) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.810 (+/-0.009) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 8}
# 0.732 (+/-0.008) for {'max_features': 'log2', 'n_estimators': 9, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.750 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 18, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.769 (+/-0.025) for {'max_features': 'log2', 'n_estimators': 27, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.771 (+/-0.030) for {'max_features': 'log2', 'n_estimators': 36, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.781 (+/-0.023) for {'max_features': 'log2', 'n_estimators': 45, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.793 (+/-0.013) for {'max_features': 'log2', 'n_estimators': 54, 'max_depth': 30, 'min_samples_leaf': 10}
# 0.796 (+/-0.014) for {'max_features': 'log2', 'n_estimators': 63, 'max_depth': 30, 'min_samples_leaf': 10}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.89      0.85      0.87      1573
#           1       0.86      0.89      0.87      1555
#
# avg / total       0.87      0.87      0.87      3128
#
#
# # Tuning hyper-parameters recall
